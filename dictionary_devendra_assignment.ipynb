# %%
# 1. Create a dictionary using user input.
# employee_dict = { 
#                  "John" : {"salary" : 5000, "department" : "Sales"},
#                  "Mike" : {"salary" : 6000, "department" : "Marketing"},
#                  "Sara" : {"salary" : 7000, "department" : "Operations"}
#                  }

employee_dict = {}
for i in range(3):
    name = input('Enter employee name: ')
    salary = int(input('Enter salary: '))
    dept = input('Enter department: ')
    employee_dict[name] = {'salary': salary, 'department': dept}

print(employee_dict)
# Out:
# {'Mike': {'salary': 90000, 'department': 'Sales'}, 'Jennifer': {'salary': 50000, 'department': 'HR'}, 'Scott': {'salary': 100000, 'department': 'CFO'}}

# %%
# 2. Create a dictionary using user input.
# employee_dict={
#                'name' : [ 'john' , 'mike' , 'sara'],
#                'salary' : [ '5000' , '6000' , '7000'] , 
#                'department' : ['sales' , 'marketing' , 'operartions' ]
#              }

employee_dict = {'name': [], 'salary': [], 'department': []}

for i in range(3):
    name = input('Enter name: ')
    salary = input('Enter salary: ')
    dept = input('Enter department: ')
    
    employee_dict['name'].append(name)
    employee_dict['salary'].append(salary)
    employee_dict['department'].append(dept)

print(employee_dict)
# Out:
# {'name': ['Ram', 'Raju', 'Ron'], 'salary': ['70000', '50000', '45000'], 'department': ['Operations', 'Staff', 'HR']}

# %%
# 3. Create a dictionary where you have to take 3 inputs from the user and take keys from this list.
# l1=[ 'name' , 'salary' , 'department' ]
# employee_dict={
#                'name' : [ 'john' , 'mike' , 'sara'],
#                'salary' : [ '5000' , '6000' , '7000'] , 
#                'department' : ['sales' , 'marketing' , 'operartions' ]
#              }

l1 = ['name', 'salary', 'department']
employee_dict = {}

for key in l1:
    employee_dict[key] = []

for i in range(3):
    for key in l1:
        value = input(f'Enter {key}: ')
        employee_dict[key].append(value)

print(employee_dict)
# Out:
# Enter name:  John
# Enter salary:  70000
# Enter department:  HR
# Enter name:  Tim
# Enter salary:  90000
# Enter department:  Admin
# Enter name:  Noel
# Enter salary:  90000
# Enter department:  Operations
# {'name': ['John', 'Tim', 'Noel'], 'salary': ['70000', '90000', '90000'], 'department': ['HR', 'Admin', 'Operations']}

# %%
# 4. Create a list of 4 dictionaries and each dictionary holds name, roll_no, city, and stream of each student.
# l1=[ 
#        {'name' : 'ajay', 'roll_no': '001', 'city' : 'pune', 'stream':'science' },
#        {'name' : 'anuj', 'roll_no': '002', 'city' : 'mumbai', 'stream':'commerce' }, 
#        {'name' : 'anil', 'roll_no': '003', 'city' : 'agra', 'stream':'arts' }, 
#      ]

l1 = []

for i in range(4):
    student = {}
    student['name'] = input('Enter name: ')
    student['roll_no'] = input('Enter roll no: ')
    student['city'] = input('Enter city: ')
    student['stream'] = input('Enter stream: ')
    l1.append(student)

print(l1)
# Out:
# Enter name:  Rahul
# Enter roll no:  29
# Enter city:  Pune
# Enter stream:  SCI
# Enter name:  Ruhi
# Enter roll no:  99
# Enter city:  Delhi
# Enter stream:  SCI
# Enter name:  Dev
# Enter roll no:  79
# Enter city:  Pune
# Enter stream:  SCI
# Enter name:  Ravi
# Enter roll no:  21
# Enter city:  BLR
# Enter stream:  COM
# [{'name': 'Rahul', 'roll_no': '29', 'city': 'Pune', 'stream': 'SCI'}, {'name': 'Ruhi', 'roll_no': '99', 'city': 'Delhi', 'stream': 'SCI'}, {'name': 'Dev', 'roll_no': '79', 'city': 'Pune', 'stream': 'SCI'}, {'name': 'Ravi', 'roll_no': '21', 'city': 'BLR', 'stream': 'COM'}]

# %%
# 5. Create a dictionary called fruit_dict with the following key-value pairs: "apple" : 1, "banana" : 2, "orange" : 3. Also print fruit_dict.

fruit_dict = {'apple': 1, 'banana': 2, 'orange': 3}
print(fruit_dict)
# Out:
# {'apple': 1, 'banana': 2, 'orange': 3}

# %%
# 6. Write a program to add a fruit mango in the fruit_dict and print all the fruit names.

fruit_dict = {'apple': 1, 'banana': 2, 'orange': 3}
fruit_dict['mango'] = 4

for fruit in fruit_dict:
    print(fruit)
# Out:
# apple
# banana
# orange
# mango

# %%
# 7. Write a program to print the serial order of all the fruits in fruit_dict.

fruit_dict = {'apple': 1, 'banana': 2, 'orange': 3, 'mango': 4}

for fruit, number in fruit_dict.items():
    print(f'{number}. {fruit}')
# Out:
# 1. apple
# 2. banana
# 3. orange
# 4. mango

# %%
# 8. Write a program to create a dictionary which contains the fruit name and their prices(float). Take fruit name and prices from user. Create for 5 fruits.

fruit_prices = {}

for i in range(5):
    fruit = input('Enter fruit name: ')
    price = float(input('Enter price: '))
    fruit_prices[fruit] = price

print(fruit_prices)
# Out:
# Enter fruit name:  Orange
# Enter price:  30
# Enter fruit name:  Apple
# Enter price:  20
# Enter fruit name:  Mango
# Enter price:  1000
# Enter fruit name:  watermelon
# Enter price:  100
# Enter fruit name:  Jackfruit
# Enter price:  120
# {'Orange': 30.0, 'Apple': 20.0, 'Mango': 1000.0, 'watermelon': 100.0, 'Jackfruit': 120.0}

# %%
# 9. Write a program to count the frequency of each word in the given sentence: "the quick brown fox jumps over the lazy dog".

sentence = 'the quick brown fox jumps over the lazy dog'
words = sentence.split()
word_count = {}

for word in words:
    if word in word_count:
        word_count[word] += 1
    else:
        word_count[word] = 1

print(word_count)
# Out:
# {'the': 2, 'quick': 1, 'brown': 1, 'fox': 1, 'jumps': 1, 'over': 1, 'lazy': 1, 'dog': 1}

# %%
# 10. Create a dictionary my_dict with three key-value pairs: "name" : "John", "age" : 30, "city" : "New York".
# Write a program to check if the key "name" is in my_dict.
# Write a program to check if the value "Chicago" is in my_dict.
# Write a program to get the length of my_dict.
# Write a program to clear all the elements in my_dict.

my_dict = {'name': 'John', 'age': 30, 'city': 'New York'}

# Check if key 'name' exists
if 'name' in my_dict:
    print('name is in my_dict')

# Check if value 'Chicago' exists
if 'Chicago' in my_dict.values():
    print('Chicago is in my_dict')
else:
    print('Chicago is not in my_dict')

# Get length
print('Length:', len(my_dict))

# Clear dictionary
my_dict.clear()
print('After clear:', my_dict)
# Out:
# name is in my_dict
# Chicago is not in my_dict
# Length: 3
# After clear: {}

# %%
# 11. Create two dictionaries dict1 and dict2 with the following key-value pairs: "a" : 1, "b" : 2, "c" : 3 and "c" : 4, "d" : 5, "e" : 6 respectively.
# Write a program to merge dict2 into dict1.
# Write a program to create a new dictionary that contains only the key-value pairs that are common in both dict1 and dict2.
# Write a program to remove a key-value pair from dict1.

dict1 = {'a': 1, 'b': 2, 'c': 3}
dict2 = {'c': 4, 'd': 5, 'e': 6}

# Merge dict2 into dict1
dict1.update(dict2)
print('Merged dict1:', dict1)

# Common keys
dict1 = {'a': 1, 'b': 2, 'c': 3}
dict2 = {'c': 4, 'd': 5, 'e': 6}
common = {key: dict1[key] for key in dict1 if key in dict2}
print('Common keys:', common)

# Remove key-value pair
del dict1['a']
print('After removing a:', dict1)
# Out:
# Merged dict1: {'a': 1, 'b': 2, 'c': 4, 'd': 5, 'e': 6}
# Common keys: {'c': 3}
# After removing a: {'b': 2, 'c': 3}

# %%
# 12. Write a program to sort a dictionary in ascending and descending both.
# use d = {'oil':230, 'clip':150, 'stud':175, 'Nut':35}

d = {'oil': 230, 'clip': 150, 'stud': 175, 'Nut': 35}

# Ascending order
ascending = dict(sorted(d.items(), key=lambda x: x[1]))
print('Ascending:', ascending)

# Descending order
descending = dict(sorted(d.items(), key=lambda x: x[1], reverse=True))
print('Descending:', descending)
# Out:
# Ascending: {'Nut': 35, 'clip': 150, 'stud': 175, 'oil': 230}
# Descending: {'oil': 230, 'stud': 175, 'clip': 150, 'Nut': 35}

# %%
# 13. Write a program to check whether the dictionary is empty or not.

d = {}

if len(d) == 0:
    print('Dictionary is empty')
else:
    print('Dictionary is not empty')
# Out:
# Dictionary is empty

# %%
# 14. Create a dictionary employee_dict with the following key-value pairs: "John" : {"salary" : 5000, "department" : "Sales"}, "Mike" : {"salary" : 6000, "department" : "Marketing"}, "Sara" : {"salary" : 7000, "department" : "Operations"}.
# Write a program to find the employee with the highest salary in employee_dict.
# Write a program to find the average salary of all employees in employee_dict.
# Write a program to add a new employee to employee_dict.
# Write a program to remove an employee from employee_dict.

employee_dict = {
    'John': {'salary': 5000, 'department': 'Sales'},
    'Mike': {'salary': 6000, 'department': 'Marketing'},
    'Sara': {'salary': 7000, 'department': 'Operations'}
}

# Find employee with highest salary
max_emp = ''
max_sal = 0
for emp, details in employee_dict.items():
    if details['salary'] > max_sal:
        max_sal = details['salary']
        max_emp = emp
print('Highest paid employee:', max_emp)

# Average salary
total = 0
for emp in employee_dict:
    total += employee_dict[emp]['salary']
avg = total / len(employee_dict)
print('Average salary:', avg)

# Add new employee
employee_dict['Tom'] = {'salary': 5500, 'department': 'IT'}
print('After adding Tom:', employee_dict)

# Remove employee
del employee_dict['John']
print('After removing John:', employee_dict)
# Out:
# Highest paid employee: Sara
# Average salary: 6000.0
# After adding Tom: {'John': {'salary': 5000, 'department': 'Sales'}, 'Mike': {'salary': 6000, 'department': 'Marketing'}, 'Sara': {'salary': 7000, 'department': 'Operations'}, 'Tom': {'salary': 5500, 'department': 'IT'}}
# After removing John: {'Mike': {'salary': 6000, 'department': 'Marketing'}, 'Sara': {'salary': 7000, 'department': 'Operations'}, 'Tom': {'salary': 5500, 'department': 'IT'}}

# %%
# 15. Suppose you are working in a retail store and you want to keep track of sales by month. Write a program to create a dictionary sales_dict that stores the monthly sales data as follows:
# Month: Jan, Sales: 5000
# Month: Feb, Sales: 7000
# Month: Mar, Sales: 4500
# Month: Apr, Sales: 9000
# Month: May, Sales: 6000
# Write a program to:
# Print the sales in January.
# Print the total sales for the first quarter (Jan to Mar).
# Print the months in which sales were greater than 6000.
# Add the sales data for June (8000) to the dictionary.
# Remove the sales data for April from the dictionary.

sales_dict = {'Jan': 5000, 'Feb': 7000, 'Mar': 4500, 'Apr': 9000, 'May': 6000}

# Sales in January
print('Jan sales:', sales_dict['Jan'])

# Total sales for first quarter
q1_sales = sales_dict['Jan'] + sales_dict['Feb'] + sales_dict['Mar']
print('Q1 sales:', q1_sales)

# Months with sales > 6000
for month, sales in sales_dict.items():
    if sales > 6000:
        print(f'{month} has sales > 6000')

# Add June
sales_dict['Jun'] = 8000
print('After adding June:', sales_dict)

# Remove April
del sales_dict['Apr']
print('After removing April:', sales_dict)
# Out:
# Jan sales: 5000
# Q1 sales: 16500
# Feb has sales > 6000
# Apr has sales > 6000
# After adding June: {'Jan': 5000, 'Feb': 7000, 'Mar': 4500, 'Apr': 9000, 'May': 6000, 'Jun': 8000}
# After removing April: {'Jan': 5000, 'Feb': 7000, 'Mar': 4500, 'May': 6000, 'Jun': 8000}

# %%
# 16. You have been given the following data about the number of COVID-19 cases in different countries:
# cases{ "USA": 3500000, "India": 2300000, "Brazil": 1800000, "Russia": 1200000, "France": 800000, "UK": 700000, "Turkey": 650000, "Italy": 600000, "Spain": 550000, "Germany": 500000 }
# Write a program to find the top 3 countries with the highest number of COVID-19 cases.

cases = {
    'USA': 3500000, 'India': 2300000, 'Brazil': 1800000, 
    'Russia': 1200000, 'France': 800000, 'UK': 700000, 
    'Turkey': 650000, 'Italy': 600000, 'Spain': 550000, 'Germany': 500000
}

# Sort by cases in descending order
sorted_cases = sorted(cases.items(), key=lambda x: x[1], reverse=True)

# Get top 3
print('Top 3 countries:')
for i in range(3):
    print(f'{i+1}. {sorted_cases[i][0]}: {sorted_cases[i][1]}')
# Out:
# Top 3 countries:
# 1. USA: 3500000
# 2. India: 2300000
# 3. Brazil: 1800000

# %%
# 17. You are given a dictionary sales_data containing sales information for a company's products. Each key-value pair in the dictionary represents a product's name and its corresponding sales in dollars for the year.
# sales_data = { 'Product A': 15000, 'Product B': 25000, 'Product C': 30000, 'Product D': 40000, 'Product E': 50000 }
# Write a program to calculate the total sales for the company.
# Write a program to calculate the average sales per product.
# Write a program to find the best-selling product.

sales_data = {'Product A': 15000, 'Product B': 25000, 'Product C': 30000, 'Product D': 40000, 'Product E': 50000}

# Total sales
total = 0
for product in sales_data:
    total += sales_data[product]
print('Total sales:', total)

# Average sales
avg = total / len(sales_data)
print('Average sales:', avg)

# Best-selling product
best_product = ''
max_sales = 0
for product, sales in sales_data.items():
    if sales > max_sales:
        max_sales = sales
        best_product = product
print('Best-selling product:', best_product)
# Out:
# Total sales: 160000
# Average sales: 32000.0
# Best-selling product: Product E
